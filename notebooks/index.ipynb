# %% [markdown]
# # Proyectos IA — Notebooks
#
# Repositorio académico con 4 proyectos.
#
# Selecciona un notebook abajo para abrirlo en Jupyter.
#
# ---

# %% [markdown]
# ## 1-game — Juego con Pygame + MLP
#
# | Notebook | Descripción |
# |---|---|
# | [`1-game/docs/notebooks/explicacion_juego_pygame_mlp.ipynb`](../1-game/docs/notebooks/explicacion_juego_pygame_mlp.ipynb) | Explicación paso a paso del juego y el MLP |
#
# **Ejecutar:** `python -m 1-game.src.main`

# %% [markdown]
# ## 2-CNN — CNN para clasificar animales
#
# | Notebook | Descripción |
# |---|---|
# | [`2-CNN/CNN.ipynb`](../2-CNN/CNN.ipynb) | Notebook principal de la CNN (original) |
# | [`2-CNN/CNNriesgo.ipynb`](../2-CNN/CNNriesgo.ipynb) | Notebook de riesgo/experimentos |
# | [`2-CNN/docs/notebooks/explicacion_cnn_animales_paso_a_paso.ipynb`](../2-CNN/docs/notebooks/explicacion_cnn_animales_paso_a_paso.ipynb) | Explicación paso a paso de la CNN |
#
# **Ejecutar:** `./scripts/cnn.fish` o `python 2-CNN/train.py --config 2-CNN/config/default.yaml`
#
# Requiere dataset en `2-CNN/dataset/` (configurable vía `CNN_DATASET_DIR`).

# %% [markdown]
# ## 3-RNN — Autocompletado de código C
#
# | Notebook | Descripción |
# |---|---|
# | [`3-RNN/notebooks/entrenamiento.ipynb`](../3-RNN/notebooks/entrenamiento.ipynb) | Entrenamiento del RNN vanilla char-level |
# | [`3-RNN/docs/notebooks/explicacion_rnn_autocomplete_paso_a_paso.ipynb`](../3-RNN/docs/notebooks/explicacion_rnn_autocomplete_paso_a_paso.ipynb) | Explicación paso a paso del RNN |
#
# **Ejecutar:** `./scripts/rnn.fish` o `python 3-RNN/src/train.py --epochs 80`

# %% [markdown]
# ## 4-RAG — RAG sobre seguridad pública en México
#
# | Notebook | Descripción |
# |---|---|
# | [`4-RAG/notebooks/rag_seguridad_mexico.ipynb`](../4-RAG/notebooks/rag_seguridad_mexico.ipynb) | Pipeline RAG completo: chunking, embeddings, ChromaDB, generación |
#
# **Ejecutar:** `./scripts/rag.fish --rag` o `python 4-RAG/run_pipeline.py --rag`
#
# Requiere Ollama + `qwen2.5:7b-instruct`.

# %% [markdown]
# ---
#
# **Total: 7 notebooks** · Python 3.11.9 · Sin GPU requerida
#
# Para lanzar Jupyter: `./scripts/jupyter.fish` o `./scripts/jupyter.fish lab`
